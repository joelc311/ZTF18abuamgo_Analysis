# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

path_04 = '/Users/joel/Library/CloudStorage/OneDrive-UniversityofSouthampton/Post Grad/ZTF18abuamgo_CLAGN_Project/2009_Analysis/'
path_22 = '/Users/joel/Library/CloudStorage/OneDrive-UniversityofSouthampton/Post Grad/ZTF18abuamgo_CLAGN_Project/2022_Analysis/'
path_24 = '/Users/joel/Library/CloudStorage/OneDrive-UniversityofSouthampton/Post Grad/ZTF18abuamgo_CLAGN_Project/2024_Analysis/'

fur_results_04 = pd.read_csv(path_04 + 'mcmc_fur_results.csv') # Combined line complex parameters
fur_results_22 = pd.read_csv(path_22 + 'mcmc_fur_results.csv')
fur_results_24 = pd.read_csv(path_24 + 'mcmc_fur_results.csv')

fur_results_22
# Out:
#    Unnamed: 0 line_comp          fwhm     fwhm_err        sigma   sigma_err  \
# 0           0       OII      0.000000     0.000000     0.000000    0.000000
# 1           1     NeIII      0.000000     0.000000     0.000000    0.000000
# 2           2       Hep   2820.266418   552.633244  1181.217940  231.735381
# 3           3        Hd   4106.640549   383.485595  1720.580351  160.754730
# 4           4        Hg   4744.367345   292.683014  1987.806598  122.659569
# 5           5        Hb   5055.909447   231.206606  5710.351177  171.547027
# 6           6       HeI  13923.883429  1046.677873  5836.509982  439.076773
# 7           7        OI      0.000000     0.000000     0.000000    0.000000
# 8           8        Ha   4449.927552    71.890732  1864.198487   30.124472
#
#            ew     ew_err         peak  peak_err         area    area_err  \
# 0    0.000000   0.000000     0.000000  0.000000     0.000000    0.000000
# ...

# %%
# Get Balmer line fluxes
Hb_04 = fur_results_04.loc[5]['area']
Ha_04 = fur_results_04.loc[8]['area']
Hg_04 = fur_results_04.loc[4]['area']
Hd_04 = fur_results_04.loc[3]['area']

Hb_22 = fur_results_22.loc[5]['area']
Ha_22 = fur_results_22.loc[8]['area']
Hg_22 = fur_results_22.loc[4]['area']
Hd_22 = fur_results_22.loc[3]['area']

# %%
# Balmer line flux ratios
Ha_frac_22 = Ha_22/Hb_22
Hg_frac_22 = Hg_22/Hb_22
Hd_frac_22 = Hd_22/Hb_22

print('2022 Hb Flux Ratios:')
print('Ha/Hb: ' + str(Ha_frac_22))
print('Hg/Hb: ' + str(Hg_frac_22))
print('Hd/Hb: ' + str(Hd_frac_22))

Ha_frac_04 = Ha_22/Hb_04
Hg_frac_04 = Hg_22/Hb_04
Hd_frac_04 = Hd_22/Hb_04

print('')
print('2009 Hb Flux Ratios:')
print('Ha/Hb: ' + str(Ha_frac_04))
print('Hg/Hb: ' + str(Hg_frac_04))
print('Hd/Hb: ' + str(Hd_frac_04))
# Out:
# 2022 Hb Flux Ratios:
# Ha/Hb: 2.007450397038374
# Hg/Hb: 0.4313109146442969
# Hd/Hb: 0.23179680490609245
#
# 2009 Hb Flux Ratios:
# Ha/Hb: 3.656402071023375
# Hg/Hb: 0.7855965576469717
# Hd/Hb: 0.4221983859554544

# %%
Ha_frac_22
# Out:
# 2.007450397038374
